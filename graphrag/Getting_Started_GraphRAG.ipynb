# %%
# %pip install langchain
# %pip install langchain-community
# %pip install langchain-neo4j       # Official Neo4j LangChain integration
# %pip install langchain-openai
# %pip install langchain-experimental  # LLMGraphTransformer
# %pip install langgraph             # Agentic workflow engine

# %%
import os
from dotenv import load_dotenv

load_dotenv()  # Load from .env file

# --- API Keys ---
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY", "sk-your-key-here")

# --- Neo4j Connection ---
# Option A: Local Neo4j Desktop / Docker
os.environ["NEO4J_URI"]      = os.getenv("NEO4J_URI",      "bolt://localhost:7687")
os.environ["NEO4J_USERNAME"] = os.getenv("NEO4J_USERNAME", "neo4j")
os.environ["NEO4J_PASSWORD"] = os.getenv("NEO4J_PASSWORD", "GraphRag")  # Replace with your actual password

# %%
from langchain_neo4j import Neo4jGraph

graph = Neo4jGraph(
    url=os.environ["NEO4J_URI"],
    username=os.environ["NEO4J_USERNAME"],
    password=os.environ["NEO4J_PASSWORD"],
    enhanced_schema=True,   # Richer schema for Cypher generation
    sanitize=True,          # Clean unsafe characters
    refresh_schema=True,    # Always fetch latest schema 
)
print(graph.url)
# Out:
# ---------------------------------------------------------------------------
# ServiceUnavailable                        Traceback (most recent call last)
# File ~/graph-rag/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_bolt_socket.py:335, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     328 s = cls._connect_secure(
#     329     resolved_address,
#     330     tcp_timeout,
#    (...)    333     ssl_context,
#     334 )
# --> 335 agreed_version, handshake, response = s._handshake(
#     336     resolved_address, deadline
#     337 )
#     338 return s, agreed_version, handshake, response
#
# File ~/graph-rag/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_bolt_socket.py:267, in BoltSocket._handshake(self, resolved_address, deadline)
#     266     self.close()
# --> 267     raise ServiceUnavailable(
#     268         f"Cannot to connect to Bolt service on {resolved_address!r} "
#     269         "(looks like HTTP)"
#     270     )
#     271 elif response[-1] == 0xFF:
#     272     # manifest style handshake
#
# ServiceUnavailable: Cannot to connect to Bolt service on ResolvedIPv4Address(('127.0.0.1', 7474)) (looks like HTTP)
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# File ~/graph-rag/.venv/lib/python3.12/site-packages/langchain_neo4j/graphs/neo4j_graph.py:379, in Neo4jGraph.__init__(self, url, username, password, database, timeout, sanitize, refresh_schema, driver_config, enhanced_schema)
#     378 try:
# --> 379     self._driver.verify_connectivity()
#     380 except neo4j.exceptions.ConfigurationError:
#
# File ~/graph-rag/.venv/lib/python3.12/site-packages/neo4j/_sync/driver.py:1090, in Driver.verify_connectivity(self, **config)
#    1089 session_config = self._read_session_config(config)
# -> 1090 self._get_server_info(session_config)
#
# File ~/graph-rag/.venv/lib/python3.12/site-packages/neo4j/_sync/driver.py:1305, in Driver._get_server_info(self, session_config)
#    1304 with self._session(session_config) as session:
# -> 1305     return session._get_server_info()
#
# File ~/graph-rag/.venv/lib/python3.12/site-packages/neo4j/_sync/work/session.py:180, in Session._get_server_info(self)
#     179 assert not self._connection
# --> 180 self._connect(
#     181     READ_ACCESS, liveness_check_timeout=0, unprepared=True
#     182 )
#     183 server_info = self._connection.server_info
#
# File ~/graph-rag/.venv/lib/python3.12/site-packages/neo4j/_sync/work/session.py:133, in Session._connect(self, access_mode, **acquire_kwargs)
#     132 try:
# --> 133     super()._connect(
#     134         access_mode, auth=self._config.auth, **acquire_kwargs
#     135     )
#     136 except asyncio.CancelledError:
#
# File ~/graph-rag/.venv/lib/python3.12/site-packages/neo4j/_sync/work/workspace.py:199, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     198 acquire_kwargs_.update(acquire_kwargs)
# --> 199 self._connection = self._pool.acquire(**acquire_kwargs_)
#     200 if (
#     201     target_db.guessed
#     202     and not self._pinned_database
#    (...)    206     # support SSR.
#     207     # => we need to fall back to explicit home database resolution
#
# File ~/graph-rag/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:675, in BoltPool.acquire(self, access_mode, timeout, database, bookmarks, auth, liveness_check_timeout, unprepared, database_callback)
#     674 deadline = Deadline.from_timeout_or_deadline(timeout)
# --> 675 return self._acquire(
#     676     self.address, auth, deadline, liveness_check_timeout, unprepared
#     677 )
#
# File ~/graph-rag/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:416, in IOPool._acquire(self, address, auth, deadline, liveness_check_timeout, unprepared)
#     415 log.debug("[#0000]  _: <POOL> trying to hand out new connection")
# --> 416 return connection_creator()
#
# File ~/graph-rag/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:230, in IOPool._acquire_new_later.<locals>.connection_creator()
#     229 try:
# --> 230     connection = self.opener(
#     231         address, auth or self.pool_config.auth, deadline
#     232     )
#     233 except ServiceUnavailable:
#
# File ~/graph-rag/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:636, in BoltPool.open.<locals>.opener(addr, auth_manager, deadline)
#     635 def opener(addr, auth_manager, deadline):
# --> 636     return Bolt.open(
#     637         addr,
#     638         auth_manager=auth_manager,
#     639         deadline=deadline,
#     640         routing_context=None,
#     641         pool_config=pool_config,
#     642     )
#
# File ~/graph-rag/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_bolt.py:368, in Bolt.open(cls, address, auth_manager, deadline, routing_context, pool_config)
#     366     deadline = Deadline(None)
# --> 368 s, protocol_version, handshake, data = BoltSocket.connect(
#     369     address,
#     370     tcp_timeout=pool_config.connection_timeout,
#     371     deadline=deadline,
#     372     custom_resolver=pool_config.resolver,
#     373     ssl_context=pool_config.get_ssl_context(),
#     374     keep_alive=pool_config.keep_alive,
#     375 )
#     377 pool_config.protocol_version = protocol_version
#
# File ~/graph-rag/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_bolt_socket.py:380, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     379 error_strs = "\n".join(map(str, errors))
# --> 380 raise ServiceUnavailable(
#     381     f"Couldn't connect to {address} (resolved to {address_strs}):"
#     382     f"\n{error_strs}"
#     383 ) from errors[0]
#
# ServiceUnavailable: Couldn't connect to localhost:7474 (resolved to ('127.0.0.1:7474',)):
# Cannot to connect to Bolt service on ResolvedIPv4Address(('127.0.0.1', 7474)) (looks like HTTP)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 from langchain_neo4j import Neo4jGraph
#       2
# ----> 3 graph = Neo4jGraph(
#       4     url=os.environ["NEO4J_URI"],
#       5     username=os.environ["NEO4J_USERNAME"],
#       6     password=os.environ["NEO4J_PASSWORD"],
#
# File ~/graph-rag/.venv/lib/python3.12/site-packages/langchain_neo4j/graphs/neo4j_graph.py:386, in Neo4jGraph.__init__(self, url, username, password, database, timeout, sanitize, refresh_schema, driver_config, enhanced_schema)
#     381     raise ValueError(
#     382         "Could not connect to Neo4j database. "
#     383         "Please ensure that the driver config is correct"
#     384     )
#     385 except neo4j.exceptions.ServiceUnavailable:
# --> 386     raise ValueError(
#     387         "Could not connect to Neo4j database. "
#     388         "Please ensure that the url is correct"
#     389     )
#     390 except neo4j.exceptions.AuthError:
#     391     raise ValueError(
#     392         "Could not connect to Neo4j database. "
#     393         "Please ensure that the username and password are correct"
#     394     )
#
# ValueError: Could not connect to Neo4j database. Please ensure that the url is correct

# %%
from langchain_openai import OpenAIEmbeddings,ChatOpenAI

llm=ChatOpenAI(model_name="gpt-4o")
llm
# Out:
# ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x1369572f0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x139c084a0>, root_client=<openai.OpenAI object at 0x1368354c0>, root_async_client=<openai.AsyncOpenAI object at 0x136957530>, model_name='gpt-4o', model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True)

# %%
from langchain_core.documents import Document
text="""
Elon Reeve Musk (born June 28, 1971) is a businessman and investor known for his key roles in space
company SpaceX and automotive company Tesla, Inc. Other involvements include ownership of X Corp.,
formerly Twitter, and his role in the founding of The Boring Company, xAI, Neuralink and OpenAI.
He is one of the wealthiest people in the world; as of July 2024, Forbes estimates his net worth to be
US$221 billion.Musk was born in Pretoria to Maye and engineer Errol Musk, and briefly attended
the University of Pretoria before immigrating to Canada at age 18, acquiring citizenship through
his Canadian-born mother. Two years later, he matriculated at Queen's University at Kingston in Canada.
Musk later transferred to the University of Pennsylvania and received bachelor's degrees in economics
 and physics. He moved to California in 1995 to attend Stanford University, but dropped out after
  two days and, with his brother Kimbal, co-founded online city guide software company Zip2.
 """
documents=[Document(page_content=text)]
documents
# Out:
# [Document(metadata={}, page_content="\nElon Reeve Musk (born June 28, 1971) is a businessman and investor known for his key roles in space\ncompany SpaceX and automotive company Tesla, Inc. Other involvements include ownership of X Corp.,\nformerly Twitter, and his role in the founding of The Boring Company, xAI, Neuralink and OpenAI.\nHe is one of the wealthiest people in the world; as of July 2024, Forbes estimates his net worth to be\nUS$221 billion.Musk was born in Pretoria to Maye and engineer Errol Musk, and briefly attended\nthe University of Pretoria before immigrating to Canada at age 18, acquiring citizenship through\nhis Canadian-born mother. Two years later, he matriculated at Queen's University at Kingston in Canada.\nMusk later transferred to the University of Pennsylvania and received bachelor's degrees in economics\n and physics. He moved to California in 1995 to attend Stanford University, but dropped out after\n  two days and, with his brother Kimbal, co-founded online city guide software company Zip2.\n ")]

# %%
from langchain_experimental.graph_transformers import LLMGraphTransformer
llm_transformer=LLMGraphTransformer(llm=llm)

# %%
graph_documents=llm_transformer.convert_to_graph_documents(documents)
# Out:
# /Users/sourangshupal/Downloads/graph-rag/.venv/lib/python3.12/site-packages/pydantic/main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='parsed', input_value=DynamicGraph(nodes=[Simpl...n', type='co-founder')]), input_type=DynamicGraph])
#   return self.__pydantic_serializer__.to_python(

# %%
print(len(graph_documents))
# Out:
# 1

# %%
graph_documents[0].nodes[:-5]
# Out:
# [Node(id='Elon Reeve Musk', type='Person', properties={}),
#  Node(id='Spacex', type='Organization', properties={}),
#  Node(id='Tesla, Inc.', type='Organization', properties={}),
#  Node(id='X Corp.', type='Organization', properties={}),
#  Node(id='The Boring Company', type='Organization', properties={}),
#  Node(id='Xai', type='Organization', properties={}),
#  Node(id='Neuralink', type='Organization', properties={}),
#  Node(id='Openai', type='Organization', properties={}),
#  Node(id='Forbes', type='Organization', properties={}),
#  Node(id='Pretoria', type='Location', properties={}),
#  Node(id='Maye Musk', type='Person', properties={}),
#  Node(id='Errol Musk', type='Person', properties={}),
#  Node(id='University Of Pretoria', type='Organization', properties={}),
#  Node(id='Canada', type='Location', properties={}),
#  Node(id="Queen'S University", type='Organization', properties={})]

# %%
graph_documents[0].relationships
# Out:
# [Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id='Spacex', type='Organization', properties={}), type='LEADER', properties={}),
#  Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id='Tesla, Inc.', type='Organization', properties={}), type='LEADER', properties={}),
#  Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id='X Corp.', type='Organization', properties={}), type='OWNER', properties={}),
#  Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id='The Boring Company', type='Organization', properties={}), type='FOUNDER', properties={}),
#  Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id='Xai', type='Organization', properties={}), type='FOUNDER', properties={}),
#  Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id='Neuralink', type='Organization', properties={}), type='FOUNDER', properties={}),
#  Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id='Openai', type='Organization', properties={}), type='FOUNDER', properties={}),
#  Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id='Forbes', type='Organization', properties={}), type='MENTIONED_IN', properties={}),
#  Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id='Pretoria', type='Location', properties={}), type='BORN_IN', properties={}),
#  Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id='Maye Musk', type='Person', properties={}), type='PARENT', properties={}),
#  Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id='Errol Musk', type='Person', properties={}), type='PARENT', properties={}),
#  Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id='University Of Pretoria', type='Organization', properties={}), type='ATTENDED', properties={}),
#  Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id='Canada', type='Location', properties={}), type='IMMIGRATED_TO', properties={}),
#  Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id="Queen'S University", type='Organization', properties={}), type='ATTENDED', properties={}),
#  Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id='University Of Pennsylvania', type='Organization', properties={}), type='ATTENDED', properties={}),
#  Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id='California', type='Location', properties={}), type='MOVED_TO', properties={}),
#  Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id='Stanford University', type='Organization', properties={}), type='ATTENDED', properties={}),
#  Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id='Kimbal Musk', type='Person', properties={}), type='SIBLING', properties={}),
#  Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id='Zip2', type='Organization', properties={}), type='CO-FOUNDER', properties={})]

# %% [markdown]
# ### lets Load a Dataset

# %%
### Load the dataset of movie

movie_query="""
LOAD CSV WITH HEADERS FROM
'https://raw.githubusercontent.com/tomasonjo/blog-datasets/main/movies/movies_small.csv' as row

MERGE(m:Movie{id:row.movieId})
SET m.released = date(row.released),
    m.title = row.title,
    m.imdbRating = toFloat(row.imdbRating)
FOREACH (director in split(row.director, '|') |
    MERGE (p:Person {name:trim(director)})
    MERGE (p)-[:DIRECTED]->(m))
FOREACH (actor in split(row.actors, '|') |
    MERGE (p:Person {name:trim(actor)})
    MERGE (p)-[:ACTED_IN]->(m))
FOREACH (genre in split(row.genres, '|') |
    MERGE (g:Genre {name:trim(genre)})
    MERGE (m)-[:IN_GENRE]->(g))
"""

# %%
graph

# %%
graph.query(movie_query)
# Out:
# []

# %%
graph.refresh_schema()
print(graph.schema)
# Out:
# Node properties:
# - **Movie**
#   - `id`: STRING Example: "1"
#   - `released`: DATE Min: 1964-12-16, Max: 1996-09-15
#   - `title`: STRING Example: "Toy Story"
#   - `imdbRating`: FLOAT Min: 2.4, Max: 9.3
# - **Person**
#   - `name`: STRING Example: "John Lasseter"
# - **Genre**
#   - `name`: STRING Example: "Adventure"
# Relationship properties:
#
# The relationships:
# (:Movie)-[:IN_GENRE]->(:Genre)
# (:Person)-[:DIRECTED]->(:Movie)
# (:Person)-[:ACTED_IN]->(:Movie)

# %% [markdown]
# ### TEXT 2 CQL

# %%
from langchain_neo4j import GraphCypherQAChain
chain=GraphCypherQAChain.from_llm(llm=llm,graph=graph,verbose=True, allow_dangerous_requests=True)
chain
# Out:
# GraphCypherQAChain(verbose=True, graph=<langchain_neo4j.graphs.neo4j_graph.Neo4jGraph object at 0x12fb3a9c0>, cypher_generation_chain=PromptTemplate(input_variables=['question', 'schema'], input_types={}, partial_variables={}, template='Task:Generate Cypher statement to query a graph database.\nInstructions:\nUse only the provided relationship types and properties in the schema.\nDo not use any other relationship types or properties that are not provided.\nSchema:\n{schema}\nNote: Do not include any explanations or apologies in your responses.\nDo not respond to any questions that might ask anything else than for you to construct a Cypher statement.\nDo not include any text except the generated Cypher statement.\n\nThe question is:\n{question}')
# | RunnableBinding(bound=ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x1369572f0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x139c084a0>, root_client=<openai.OpenAI object at 0x1368354c0>, root_async_client=<openai.AsyncOpenAI object at 0x136957530>, model_name='gpt-4o', model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True), kwargs={}, config={}, config_factories=[])
# | StrOutputParser(), qa_chain=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template="You are an assistant that helps to form nice and human understandable answers.\nThe information part contains the provided information that you must use to construct an answer.\nThe provided information is authoritative, you must never doubt it or try to use your internal knowledge to correct it.\nMake the answer sound as a response to the question. Do not mention that you based the result on the given information.\nHere is an example:\n\nQuestion: Which managers own Neo4j stocks?\nContext:[manager:CTL LLC, manager:JANE STREET GROUP LLC]\nHelpful Answer: CTL LLC, JANE STREET GROUP LLC owns Neo4j stocks.\n\nFollow this example when generating answers.\nIf the provided information is empty, say that you don't know the answer.\nInformation:\n{context}\n\nQuestion: {question}\nHelpful Answer:")
# | RunnableBinding(bound=ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x1369572f0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x139c084a0>, root_client=<openai.OpenAI object at 0x1368354c0>, root_async_client=<openai.AsyncOpenAI object at 0x136957530>, model_name='gpt-4o', model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True), kwargs={}, config={}, config_factories=[])
# | StrOutputParser(), graph_schema='Node properties are the following:\nMovie {id: STRING, released: DATE, title: STRING, imdbRating: FLOAT},Person {name: STRING},Genre {name: STRING}\nRelationship properties are the following:\n\nThe relationships are the following:\n(:Movie)-[:IN_GENRE]->(:Genre),(:Person)-[:DIRECTED]->(:Movie),(:Person)-[:ACTED_IN]->(:Movie)', allow_dangerous_requests=True)

# %%
response=chain.invoke({"query":"Who was the director of the moview Casino"})

response
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# cypher
# MATCH (p:Person)-[:DIRECTED]->(m:Movie {title: "Casino"})
# RETURN p.name
#
# Full Context:
# [{'p.name': 'Martin Scorsese'}]
#
# > Finished chain.
# {'query': 'Who was the director of the moview Casino',
#  'result': 'Martin Scorsese was the director of the movie Casino.'}

# %%
response=chain.invoke({"query":"tell me the genre of the movie GoldenEye"})

response
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# cypher
# MATCH (m:Movie {title: 'GoldenEye'})-[:IN_GENRE]->(g:Genre)
# RETURN g.name
#
# Full Context:
# [{'g.name': 'Adventure'}, {'g.name': 'Action'}, {'g.name': 'Thriller'}]
#
# > Finished chain.
# {'query': 'tell me the genre of the movie GoldenEye',
#  'result': 'Adventure, Action, Thriller'}

# %%
response=chain.invoke({"query":"Who was the director in movie Casino"})

response
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# cypher
# MATCH (p:Person)-[:DIRECTED]->(m:Movie {title: "Casino"})
# RETURN p.name
#
# Full Context:
# [{'p.name': 'Martin Scorsese'}]
#
# > Finished chain.
# {'query': 'Who was the director in movie Casino',
#  'result': 'Martin Scorsese was the director of the movie Casino.'}
